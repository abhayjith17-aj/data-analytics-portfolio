# %%
import pandas as pd

data = {
    'Product': ['Laptop', 'Phone', 'Tablet'],
    'Sales': [50000, 20000, 15000]
}

df = pd.DataFrame(data)

print(df)

print("\nTotal Sales:", df['Sales'].sum())
# Out:
#   Product  Sales
# 0  Laptop  50000
# 1   Phone  20000
# 2  Tablet  15000
#
# Total Sales: 85000
